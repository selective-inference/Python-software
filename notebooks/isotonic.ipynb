# %%
# %load_ext rmagic

try:
    raise ImportError # just use R
    import regreg.api as rr
    regreg_imported = True
except ImportError:
    regreg_imported = False
import numpy as np
from scipy.stats import norm as ndist
from warnings import warn
from scipy.stats import chi
# Out:
# The rmagic extension is already loaded. To reload it, use:
#   %reload_ext rmagic

# %% [markdown]
# Loading in necessary code

# %% [markdown]
# I have started writing a python package with some of this code. Rather than have you install it, I will hopefully have things so that it will
# just load what is needed.

# %%
class constraint(object):

    def __init__(self, 
                 inequality, 
                 equality, 
                 independent=False,
                 covariance=None):
        """
        Create a new inequality. If independent, then
        it is assumed that the rows of inequality
        and equality are independent (for a given covariance).
        """
        if equality is not None:
            self.equality, self.equality_offset = \
                np.asarray(equality[0]), equality[1]
            if self.equality.ndim == 2:
                dim_equality = self.equality.shape[1]
            else:
                dim_equality = self.equality.shape[0]
        else:
            self.equality = self.equality_offset = dim_equality = None

        if inequality is not None:
            self.inequality, self.inequality_offset = \
                np.asarray(inequality[0]), inequality[1]
            if self.inequality.ndim == 2:
                dim_inequality = self.inequality.shape[1]
            else:
                dim_inequality = self.inequality.shape[0]
        else:
            self.inequality = self.inequality_offset = dim_inequality = None

        if ((dim_equality is not None) and
            (dim_inequality is not None) and
            (dim_equality != dim_inequality)):
            raise ValueError('constraint dimensions do not match')

        if dim_equality is not None:
            self.dim = dim_equality
        else:
            self.dim = dim_inequality

        if covariance is None:
            covariance = np.identity(self.dim)
        self.covariance = covariance

    def impose_equality(self):
        """
        Return an equivalent constraint with the equality
        constraint enforced.
        """
        if self.equality is not None:
            M1 = np.dot(self.inequality, np.dot(self.covariance, 
                                                self.equality.T))
            M2 = np.dot(self.equality, np.dot(self.covariance, 
                                              self.equality.T))
            M3 = np.dot(M1, np.linalg.pinv(M2))
            
            equality_linear = np.dot(M3, self.equality)
            equality_offset = np.dot(M3, self.equality_offset)
            
            return constraint((self.inequality - equality_linear,
                               self.inequality_offset - equality_offset),
                              (self.equality, self.equality_offset),
                              independent=True)
        else:
            return self

    def __call__(self, Y, tol=1.e-3):
        """
        Check whether Y satisfies the linear
        inequality and equality constraints.
        """
        V1 = np.dot(self.inequality, Y) + self.inequality_offset
        test1 = np.all(V1 > -tol * np.fabs(V1).max())

        V2 = np.dot(self.equality, Y) + self.equality_offset
        test2 = np.linalg.norm(V2) < tol * np.linalg.norm(self.equality)
        return test1 and test2

    def pivots(self, direction_of_interest, Y):
        return interval_constraints(self.inequality,
                                    self.inequality_offset,
                                    self.covariance,
                                    Y,
                                    direction_of_interest)

def stack(*cons):
    """
    Combine constraints into a large constaint
    by intersection.
    """
    ineq, ineq_off = [], []
    eq, eq_off = [], []
    for con in cons:
        if con.inequality is not None:
            ineq.append(con.inequality)
            ineq_off.append(con.inequality_offset)
        if con.equality is not None:
            eq.append(con.equality)
            eq_off.append(con.equality_offset)

    ineq = np.vstack(ineq)
    ineq_off = np.hstack(ineq_off)

    eq = np.vstack(eq)
    eq_off = np.hstack(eq_off)
    return constraint((ineq, ineq_off), (eq, eq_off))

def simulate_from_constraints(con, tol=1.e-3, mu=None):
    if con.equality is not None:
        V = np.linalg.pinv(con.equality)
        a = -np.dot(V, con.equality_offset)
        P = np.identity(con.dim) - np.dot(con.equality.T, V.T)
    else:
        a = 0
        P = np.identity(con.dim)
    if con.inequality is not None:
        while True:
            Z = np.dot(P, np.random.standard_normal(con.dim)) + a
            if mu is not None:
                Z += mu
            W = np.dot(con.inequality, Z) + con.inequality_offset  
            if np.all(W > - tol * np.fabs(W).max()):
                break
        return Z
    else:
        return np.dot(P, np.random.standard_normal(con.dim)) + a

def interval_constraints(support_directions, 
                         support_offsets,
                         covariance,
                         observed_data, 
                         direction_of_interest,
                         tol = 1.e-4):
    """
    Given an affine cone constraint $Ax+b \geq 0$ (elementwise)
    specified with $A$ as `support_directions` and $b$ as
    `support_offset`, a new direction of interest $w$, and
    an observed Gaussian vector $X$ with some `covariance`, this
    function returns $w^TX$ as well as an interval
    bounding this value. 

    The interval constructed is such that the endpoints are 
    independent of $w^TX$, hence the $p$-value
    of `Kac-Rice <http://arxiv.org/abs/1308.3020>`_
    can be used to form an exact pivot.

    """

    # shorthand
    A, b, S, X, w = (support_directions,
                     support_offsets,
                     covariance,
                     observed_data,
                     direction_of_interest)

    U = np.dot(A, X) + b
    if not np.all(U > -tol * np.fabs(U).max()):
        warn('constraints not satisfied: %s' % `U`)

    Sw = np.dot(S, w)
    sigma = np.sqrt((w*Sw).sum())
    C = np.dot(A, Sw) / sigma**2
    V = (w*X).sum()
    RHS = (-b - np.dot(A, X) + V * C) / C
    pos_coords = C > tol * np.fabs(C).max()
    if np.any(pos_coords):
        lower_bound = RHS[pos_coords].max()
    else:
        lower_bound = -np.inf
    neg_coords = C < -tol * np.fabs(C).max()
    if np.any(neg_coords):
        upper_bound = RHS[neg_coords].min()
    else:
        upper_bound = np.inf

    pval = (ndist.cdf(upper_bound / sigma) - ndist.cdf(V / sigma)) / (ndist.cdf(upper_bound / sigma) - ndist.cdf(lower_bound / sigma))
    return lower_bound, V, upper_bound, sigma, pval

# %% [markdown]
# # Isotonic regression
#
# We will solve the problem
# $$
# \hat{\mu}_{+} = \text{argmin}_{\mu \in \mathbb{R}^n: \mu_{i+1} \geq \mu_i, 1 \leq i \leq n-1} \frac{1}{2} \|y-\mu\|^2_2 = \text{argmin}_{\mu \in \mathbb{R}^n: \mu_{i+1} \geq \mu_i, 1 \leq i \leq n-1} \frac{1}{2} \left[ \|P(y-\mu)\|^2_2 + \|P^{\perp}(y-\mu)\|^2_2 \right]
# $$
# with
# $$
# P = I - \frac{1}{n} 11^T.
# $$
#
# There are many ways to solve this problem of course, but we reparameterize
# $$
# \beta = D\mu, \alpha = \bar{\mu}
# $$
# where $D[i,] = e_{i+1}-e_i, 1 \leq i \leq n-1$ is the matrix of first differences.

# %% [markdown]
# We see that in $\beta$, the problem is
# $$
# \hat{\beta}_+ = \text{argmin}_{\beta \in \mathbb{R}^{n-1}: \beta_i \geq 0} \frac{1}{2} \|P(y- D^{\dagger}\beta)\|^2_2
# $$
# and
# $$
# \hat{\alpha} = \bar{y}.
# $$
# For ease of notation, we will set $X=PD^{\dagger}$ throughout.
#
# Having found $\hat{\beta}_+$ we can find $\hat{\mu}_+$ by
# $$
# \hat{\mu}_+ = \bar{y} \cdot 1 +  X\hat{\beta}_+
# $$

# %% [markdown]
# # KKT conditions
#
# The KKT conditions for the $\beta$ problem are defined in terms of a quantity analgous to the equicorrelation set:
# $$
# {\cal E} = {\cal E}(y) = \left\{i: X_i^T(y-X\hat{\beta}_+(y))=0 \right\}
# $$
# and the two blocks of the KKT conditions would be
# $$
# \begin{aligned}
# X_{\cal E}^T(y-X\hat{\beta}_+) &= 0 \\
# X_{-\cal E}^T(y-X\hat{\beta}_+) &<0  \\
# X_{\cal E}^{\dagger}y & > 0
# \end{aligned}
# $$
#
# As in the LASSO case, these equations can be solved explicitly given the value of ${\cal E}$:
# $$
# \begin{aligned}
# \hat{\beta}_{+,\cal E} &= X_{\cal E}^{\dagger}y \\
# \hat{\beta}_{+,-{\cal E}} &= 0 \\
# \max_{i \in {-\cal E}}X_i^T(I-P_{\cal E})y &< 0.
# \end{aligned}.
# $$
#
# This determines our $(A,b)$ pair:
# $$
# \begin{aligned}
# A(y) &= -X_{-{\cal E}(y)}^T(I-P_{{\cal E}(y)})y  \\
# b(y) &= 0_{-{\cal E}(y)}.
# \end{aligned}
# $$

# %%
def solve_and_find_constraints(y, subgrad_tol=1.e-4):
    """
    Solve the isotonic regression problem and return the constraints
    implied in the solution.
    
    Parameters
    ----------
    
    y : `np.float((n,))`
        Response
        
    subgrad_tol : float
        Tolerance to determine active constraints.
    
    Returns
    -------
    
    fitted : `np.float((n,))`
        Vector of fitted alues.
        
    constraints : `np.float((n-1,n))`
        Linear constraints implied by the active variables. The number of
        constraints returned depends on the number of nonzero jumps in `mu`.
    
    subgrad : `np.float((n-1,))`
        Subgradient of nonnegative constraints: it should be elementwise
        nonpositive.
        
    """
    n = y.shape[0]
    X = np.tril(np.ones((n,n)),0)[:,1:]
    X -= X.mean(0)
    
    if not regreg_imported:
        fitted = %R -i y isoreg(y)$yf
    else:
        loss = rr.squared_error(X, y)
        nonneg = rr.nonnegative(n-1)
        problem = rr.simple_problem(loss, nonneg)
        soln = problem.solve(tol=1.e-12, min_its=100)
        fitted = np.dot(X, soln) + np.mean(Y)
        
    subgrad = np.dot(X.T, y - fitted)
    active = subgrad > -subgrad_tol    
    inactive = ~active
    
    # inefficient, but this is just a prototype
    if active.sum():
        soln_active = np.linalg.pinv(X[:,active])
        P_active = np.dot(X[:,active], soln_active)
        constraints = np.vstack([- np.dot(X[:,inactive].T, np.identity(n) - P_active),
                                 soln_active])
    else:
        constraints = -X.T
        
    
    return fitted, subgrad, constraints

# %% [markdown]
# Let's check that our function works.

# %%
Y = np.random.standard_normal(10)
fitted, subgrad, constraints = solve_and_find_constraints(Y)

# %% [markdown]
# The subgradient is a subgradient of the nonnegative constraint at $\hat{\beta}_+$ so it should be elementwise nonpositive and exactly zero at
# indices $i$ where $\hat{\mu}[i+1]-\hat{\mu}[i]>0$.

# %%
print subgrad
# Out:
# [ -4.85722573e-17  -1.52655666e-16  -2.07079673e+00  -1.56007834e+00
#   -6.10536478e-01  -1.04060525e+00  -8.91721204e-01  -8.34870026e-01
#    1.63064007e-16]

# %%
print fitted[1:] - fitted[:-1]
# Out:
# [ 1.17311504  0.59133863  0.          0.          0.          0.          0.
#   0.          0.30599443]

# %% [markdown]
# It passes this check OK. As expected, the fitted values are non-decreasing.

# %% [markdown]
# Finally, we have chosen the constraint to be such that `np.dot(constraints, Y)` are elementwise non-negative. Let's verify this:

# %%
np.dot(constraints, Y)
constraints.shape
# Out:
# (9, 10)

# %% [markdown]
# # Inference for isotonic regression

# %% [markdown]
# At a first question, we might want to test whether $\mu_2=0$, say.

# %%
n = Y.shape[0]
eta = np.zeros(n)
eta[1] = 1

Vplus, eta_dot_Y, Vminus, sigma_eta, Pval = interval_constraints(constraints, \
             np.zeros(constraints.shape[0]), 
             np.identity(n),
             Y,
             eta)
print Vplus, eta_dot_Y, Vminus, sigma_eta, Pval
# Out:
# -1.24824040153 -0.0751253598249 0.516213269338 1.0 0.38413243804

# %% [markdown]
# ## A small simulation
#
# Let's make a simulation for isotonic regression at some fixed point. Of course, we can also handle
# a random point, maybe the first jump, or the largest jump?

# %%
# %%R -o mu
# mu = c(rep(0,20), rep(2.5,20), rep(5,10))
# plot(isoreg(rnorm(50)+mu), xlab='t', ylab='Y')
# lines(mu, type='s', lwd=3, col='blue')

# %%
def simulate_fixed(n, j, mu=0):
    """
    Perform isotonic regression for $y \sim N(0,I_{n \times n})$.
    
    Test whether $\mu_j=0$ after selection (i.e. fitting isotonic regression).
    
    Parameters
    ----------
    
    n, j : `int`
        The size of isotonic regression problem to consider, $n$; and which index
        to perform the test at. Later we will form intervals for $\mu_j$ as well.
    
    Returns
    -------
    
    Pval : `float`
        Exact test statistic for testing $H_0:\mu_j=0$.
    """
    
    Y = np.random.standard_normal(n) + mu
    fitted, subgrad, constraints = solve_and_find_constraints(Y)
    eta = np.zeros(n)
    eta[j] = 1
    
    return interval_constraints(constraints, \
             np.zeros(constraints.shape[0]), 
             np.identity(n),
             Y,
             eta)[-1]

# %% [markdown]
# This test uses the (usually unknown) position of the true jump in the signal. In our simulation, this jump is at $t=20$. We might also try at
# an incorrect value, say $t=10$.

# %%
P0, Pa_correct, Pa_incorrect = [], [], []
n, j_correct, j_incorrect, nsim = 50, 20, 10, 2000
for _ in range(nsim):
    P0.append(simulate_fixed(n,j))
    Pa_correct.append(simulate_fixed(n,j_correct,mu=mu))
    Pa_incorrect.append(simulate_fixed(n,j_incorrect,mu=mu))

# %%
# %%R -i P0,Pa_correct,Pa_incorrect
# plot(ecdf(P0), col='red', lwd=3)
# plot(ecdf(Pa_correct), col='blue', add=TRUE, lwd=3)
# plot(ecdf(Pa_incorrect), col='green', add=TRUE, lwd=3)
# abline(0,1)

# %% [markdown]
# Not surprisingly, and correctly, at $t=10$ the distribution is $\text{Unif}(0,1)$.

# %% [markdown]
# ## Tests at a random point

# %%
def simulate_random_constraint(n, mu=0):
    """
    Perform isotonic regression for $y \sim N(0,I_{n \times n})$.
    
    Test whether $A[j(y)]^T\mu=0$ after selection (i.e. fitting isotonic regression)
    where $j(y)$ is a randomly chosen index into the constraint matrix $A$.
        
    Parameters
    ----------
    
    n : `int`
        The size of isotonic regression problem to consider, $n$.
    
    Returns
    -------
    
    Pval : `float`
        Exact test statistic for testing $H_0:\mu_j=0$.
    """
    
    Y = np.random.standard_normal(n) + mu
    fitted, subgrad, constraints = solve_and_find_constraints(Y)
    rand_idx = np.random.randint(low=0, high=constraints.shape[0]-1)
    eta = constraints[rand_idx]
       
    return interval_constraints(constraints, \
                     np.zeros(constraints.shape[0]), 
                     np.identity(n),
                     Y,
                     eta)[-1]

# %%
P0, Pa = [], []
for _ in range(nsim):
    pval = simulate_random_constraint(n)
    P0.append(pval)
    pval = simulate_random_constraint(n, mu=mu)
    Pa.append(pval)

# %%
# %%R -i P0,Pa
# P0 = P0[P0>0]
# P0 = P0[P0<1]
# plot(ecdf(P0), col='red', lwd=3)
# Pa = Pa[Pa>0]
# Pa = Pa[Pa<1]
# plot(ecdf(Pa), col='blue', lwd=3, add=TRUE)
# abline(0,1)

# %% [markdown]
# This has almost no power to reject $H_0$, not surprisingly.

# %% [markdown]
# ## Tests for the first jump

# %%
def simulate_first_jump(n, mu=0):
    """
    Perform isotonic regression for $y \sim N(0,I_{n \times n})$.
    
    Test whether $D[j_1(y)]\mu$ where $j_1(y)$ is the index of the first jump.
    Return `None` if there are no jumps.
    
    Parameters
    ----------
    
    n : `int`
        The size of isotonic regression problem to consider, $n$.
    
    Returns
    -------
    
    Pval : `[float,None]`
        Exact test statistic for testing $H_0:\mu_j=0$.
    """
    
    Y = np.random.standard_normal(n) + mu
    fitted, subgrad, constraints = solve_and_find_constraints(Y)
    D = (np.identity(n) - np.diag(np.ones(n-1),1))[:-1]
    Dmu = np.dot(D, fitted)
    jumps = np.nonzero(Dmu)[0]
    if jumps.sum() > 0:
        first_idx = jumps.min()
        eta = D[first_idx]
       
        return interval_constraints(constraints, \
                     np.zeros(constraints.shape[0]), 
                     np.identity(n),
                     Y,
                     eta)[-1]
    else:
        return None

# %%
P0, Pa = [], []
for _ in range(nsim):
    pval = simulate_first_jump(n)
    if pval is not None:
        P0.append(pval)
    pval = simulate_first_jump(n, mu=mu)
    if pval is not None:
        Pa.append(pval)

# %%
# %%R -i P0,Pa
# P0 = P0[P0>0]
# P0 = P0[P0<1]
# plot(ecdf(P0), col='red', lwd=3)
# Pa = Pa[Pa>0]
# Pa = Pa[Pa<1]
# plot(ecdf(Pa), col='blue', lwd=3, add=TRUE)
# abline(0,1)

# %% [markdown]
# This does not seem to have much power. This would be the case if the first jump almost never happened at $t=20$.

# %% [markdown]
# ## Tests for the largest jump

# %%
def simulate_largest_jump(n, mu=0):
    """
    Perform isotonic regression for $y \sim N(0,I_{n \times n})$.
    
    Test whether $D[j_1(y)]\mu$ where $j_1(y)$ is the index of the first jump.
    Return `None` if there are no jumps.
    
    Parameters
    ----------
    
    n : `int`
        The size of isotonic regression problem to consider, $n$.
    
    Returns
    -------
    
    Pval : `[float,None]`
        Exact test statistic for testing $H_0:\mu_j=0$.
    """
    
    Y = np.random.standard_normal(n)+mu
    fitted, subgrad, constraints = solve_and_find_constraints(Y)
    active = subgrad > -1.e-3

    X = np.tril(np.ones((n,n)),0)[:,1:]
    X -= X.mean(0)
    
    D = -(np.identity(n) - np.diag(np.ones(n-1),1))[:-1]
    Dmu = np.dot(D, fitted)
    jumps = np.nonzero(Dmu)[0]
    if jumps.sum() > 0:
        max_idx = np.argmax(Dmu)
        
        soln_active = np.linalg.pinv(X[:,active])
        P_active = np.dot(X[:,active], soln_active)
        fit_matrix = P_active + np.ones((n,n), np.float) / n
        
        eta = D[max_idx]
        
        diffD = D - D[max_idx]
        indices = range(diffD.shape[0])
        indices.pop(max_idx)
        diffD = np.dot(diffD[indices], fit_matrix)
        
        all_constraints = np.vstack([-diffD, constraints])
        return interval_constraints(all_constraints, \
                     np.zeros(all_constraints.shape[0]), 
                     np.identity(n),
                     Y,
                     eta)[-1]
    else:
        return None

# %%
P0, Pa = [], []
for _ in range(nsim):
    pval = simulate_largest_jump(n)
    if pval is not None:
        P0.append(pval)
    pval = simulate_largest_jump(n, mu=mu)
    if pval is not None:
        Pa.append(pval)

# %%
# %%R -i P0,Pa
# P0 = P0[P0>0]
# P0 = P0[P0<1]
# plot(ecdf(P0), col='red', lwd=3)
# Pa = Pa[Pa>0]
# Pa = Pa[Pa<1]
# plot(ecdf(Pa), col='green', lwd=3, add=TRUE)
# plot(ecdf(Pa_correct), col='blue', lwd=3, add=TRUE)
# abline(0,1)

# %% [markdown]
# ## A $\chi^2$ test

# %% [markdown]
# Ideally, we might try pooling some or all of the jumps into some sort of $\chi^2$ test. This is indeed possible. Here, we combine the first
# $k$ jumps into a $\chi^2_k$ subject to the constraints imposed by the isotonic regression.

# %%
def tangent_space(operator, y):
    """
    Return the unit vector $\eta(y)=Ay/\|Ay\|_2$ 
    where $A$ is `operator`. It also forms a basis for the 
    tangent space of the unit sphere at $\eta(y)$.

    Parameters
    ----------

    operator : `np.float((p,q))`
    y : `np.float((q,)`

    Returns
    -------

    eta : `np.float(p)`
        Unit vector that achieves the norm of $Ay$ with $A$ as `operator`. 
    tangent_space : `np.float((p-1,p))`
        An array whose rows form a basis for the tangent space
        of the sphere at `eta`.

    """
    A = operator # shorthand
    soln = np.dot(A, y)
    norm_soln = np.linalg.norm(soln)
    eta = np.dot(A.T, soln) / norm_soln

    p, q = A.shape
    tangent_vectors = np.identity(p)[:-1]
    for tv in tangent_vectors:
        tv[:] = tv - np.dot(tv, soln) * soln / norm_soln**2

    return eta, np.dot(tangent_vectors, A)

def quadratic_test(y, operator, con):
    """
    Perform a quadratic test based on some constraints. 
    """
    A = operator # shortand
    p, q = A.shape

    eta, TA = tangent_space(A, y)

    newcon = constraint((con.inequality, 
                         con.inequality_offset),
                        (TA, np.zeros(TA.shape[0])))
    newcon = newcon.impose_equality()
    P = np.identity(q) - np.dot(np.linalg.pinv(TA), TA)
    eta = np.dot(P, eta)
    Vp, V, Vm, sigma = newcon.pivots(eta, y)[:4]
    Vp = max(0, Vp)
    
    pval = ((chi.cdf(Vm/sigma, p) - chi.cdf(V/sigma,p)) / 
            (chi.cdf(Vm/sigma, p) - chi.cdf(Vp/sigma,p)))
    return np.clip(pval, 0, 1)

# %%
def simulate_combining_jumps(n, k=3, mu=0):
    """
    Perform isotonic regression for $y \sim N(0,I_{n \times n})$.
    
    Test whether $D[j_1(y)]\mu$ where $j_1(y)$ is the index of the first jump.
    Return `None` if there are no jumps.
    
    Parameters
    ----------
    
    n : `int`
        The size of isotonic regression problem to consider, $n$.
    
    Returns
    -------
    
    Pval : `[float,None]`
        Exact test statistic for testing $H_0:\mu_j=0$.
    """
    
    Y = np.random.standard_normal(n)+mu
    fitted, subgrad, constraints = solve_and_find_constraints(Y)
    active = subgrad > -1.e-3

    X = np.tril(np.ones((n,n)),0)[:,1:]
    X -= X.mean(0)
    
    D = -(np.identity(n) - np.diag(np.ones(n-1),1))[:-1]
    Dmu = np.dot(D, fitted)
    jumps = np.nonzero(Dmu)[0]
    if jumps.sum() > 0:
        order_idx = np.argsort(Dmu)[::-1]
        
        soln_active = np.linalg.pinv(X[:,active])
        P_active = np.dot(X[:,active], soln_active)
        fit_matrix = P_active + np.ones((n,n), np.float) / n
        
        A = D[order_idx[:k]]
        Ptest = np.linalg.svd(A, full_matrices=0)[2] 
        
        orderedD = D[order_idx]
        diffD = np.diff(orderedD, 0)
        diffD = np.dot(diffD, fit_matrix)
        
        all_constraints = np.vstack([diffD, constraints])
        
        return quadratic_test(Y, Ptest, constraint((all_constraints, np.zeros(all_constraints.shape[0])), None))
    
    else:
        return None

simulate_combining_jumps(n, 3, 0)
# Out:
# 0.73960478188090284

# %%
# %connect_info
# Out:
# {
#   "stdin_port": 51039,
#   "ip": "127.0.0.1",
#   "control_port": 51040,
#   "hb_port": 51041,
#   "signature_scheme": "hmac-sha256",
#   "key": "4a545938-7eb8-4a50-ac80-07c29aea1560",
#   "shell_port": 51037,
#   "transport": "tcp",
#   "iopub_port": 51038
# }
#
# Paste the above JSON into a file, and connect with:
#     $> ipython <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> ipython <app> --existing kernel-3f3047a4-05d0-4bd0-98ff-42fb47d09539.json
# or even just:
#     $> ipython <app> --existing
# if this is the most recent IPython session you have started.

# %%
P0, Pa = [], []
nsim = 1000
for _ in range(nsim):
    pval = simulate_combining_jumps(n, 3)
    if pval is not None:
        P0.append(pval)
    pval = simulate_combining_jumps(n, 3, mu=mu)
    if pval is not None:
        Pa.append(pval)
# Out:
# -c:158: UserWarning: constraints not satisfied: array([  1.14330918e+00,   1.05496181e+00,   9.44332621e-01,
#          6.87583621e-01,   5.86615457e-01,   4.21973624e-01,
#          3.70965460e-01,   2.93908239e-01,   2.91120435e-01,
#          2.16844440e-01,   1.55435187e-01,   1.27127136e-03,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,  -6.85278796e-04,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   1.47279553e+00,   7.12048120e-01,
#          8.31928686e-01,   1.48703674e+00,   6.70710022e-01,
#          7.03724036e-01,   2.85237126e+00,   1.84557234e+00,
#          2.55827898e+00,   2.00131621e+00,   7.60397070e-02,
#          2.29236823e-01,   3.42639398e-04,   6.56501218e-01,
#          9.80616372e-01,   7.67096011e-01,   2.60828099e+00,
#          2.70827612e+00,   4.07870046e+00,   5.17684228e+00,
#          3.26721800e+00,   2.90500859e+00,   3.14629695e+00,
#          3.20228977e+00,   1.52352312e+00,   5.15646036e-01,
#          4.27011939e-01,   2.71685990e-01,   9.86665154e-01,
#          9.13144339e-01,   2.14146754e-01,   3.08350277e-01,
#          9.36539066e-01,   4.61931078e-01,   5.14526193e-01,
#          1.23962569e+00,   1.39464466e+00,   1.27127136e-03,
#          2.91120435e-01,   9.44332621e-01,   2.93565599e-01,
#          1.14296654e+00,   1.55435187e-01,   5.86615457e-01,
#          3.70965460e-01,   1.05496181e+00,   2.16844440e-01,
#          4.21973624e-01,   6.87583621e-01])
# -c:158: UserWarning: constraints not satisfied: array([  2.29084284e+00,   1.11500023e+00,   6.24776792e-01,
#          4.86234129e-01,   4.49055157e-01,   3.81789361e-01,
#          3.57861065e-01,   1.79610229e-01,   1.52585482e-01,
#          1.44483945e-01,   6.64408959e-02,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#         -1.91824676e-03,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   1.37016365e+00,   1.26815963e+00,
#          3.86238276e-01,   1.05957646e+00,   1.01533756e+00,
#          5.48202074e-01,   9.39936867e-01,   1.29680126e+00,
#          3.43074999e-01,   7.79934141e-01,   3.48958103e-01,
#          1.26818340e+00,   1.03015648e+00,   1.94221765e+00,
#          1.23437846e+00,   4.07047153e-01,   8.42245078e-01,
#          6.24621481e-01,   7.97820414e-01,   1.12305655e+00,
#          1.82683472e+00,   1.77163892e+00,   1.12793151e+00,
#          8.71790069e-01,   2.82727235e-01,   1.68623665e-01,
#          4.46150535e-01,   9.59123381e-04,   5.40049293e-02,
#          9.50918312e-01,   9.88865176e-01,   2.69321966e+00,
#          9.48882457e-01,   1.10027348e+00,   1.38830272e+00,
#          1.48047906e+00,   1.06583851e-01,   9.72270203e-02,
#          4.49055157e-01,   3.57861065e-01,   6.64408959e-02,
#          2.29084284e+00,   1.52585482e-01,   1.44483945e-01,
#          6.23817668e-01,   1.78651106e-01,   4.86234129e-01,
#          1.11500023e+00,   3.81789361e-01])
# -c:158: UserWarning: constraints not satisfied: array([  1.76731244e+00,   1.14492440e+00,   8.53963800e-01,
#          7.66297674e-01,   5.76103334e-01,   4.75138187e-01,
#          1.15151798e-01,   8.33609758e-02,   2.75225513e-02,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,  -1.68639646e-03,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   3.40525307e-01,   2.04145380e+00,
#          2.06665353e+00,   3.15134376e+00,   2.10854627e+00,
#          2.10797577e+00,   8.88628085e-01,   7.58726654e-01,
#          8.43198229e-04,   6.41715389e-01,   2.42513714e-01,
#          6.37404794e-01,   9.74111731e-01,   1.33715418e+00,
#          1.86834620e-01,   1.03165636e+00,   4.91309777e-01,
#          1.23622987e+00,   9.56292625e-01,   2.10377140e+00,
#          5.97938582e-01,   1.03073330e+00,   1.17628051e-01,
#          5.39333735e-01,   2.43423974e+00,   2.74312632e+00,
#          1.22646125e+00,   9.54100435e-01,   1.70691569e+00,
#          2.87421943e+00,   1.95526807e+00,   1.71702468e+00,
#          8.95520622e-02,   2.98861389e-01,   1.78320489e+00,
#          2.72828070e+00,   2.87652614e+00,   3.08233153e+00,
#          2.90837245e+00,   3.22367189e-01,   4.75138187e-01,
#          8.25177776e-02,   1.14308600e-01,   8.53963800e-01,
#          1.14492440e+00,   5.76103334e-01,   1.76731244e+00,
#          2.75225513e-02,   7.66297674e-01])
# -c:158: UserWarning: constraints not satisfied: array([  2.41675169e+00,   1.92940730e+00,   1.02288091e+00,
#          5.91145602e-01,   4.34878427e-01,   3.88178437e-01,
#          1.48758602e-01,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,  -7.26526523e-04,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   3.81314367e-02,   9.51887863e-01,
#          6.15191324e-01,   4.45101611e-01,   5.74615370e-01,
#          2.57671896e-01,   1.01315827e+00,   1.54155172e+00,
#          2.30250924e+00,   1.90312660e+00,   2.05741186e-01,
#          3.79406440e-01,   7.46576956e-01,   1.56569962e+00,
#          6.45801354e-04,   1.83901340e-01,   3.45585703e-01,
#          9.17976710e-01,   2.32600363e+00,   1.83956063e+00,
#          2.98512056e+00,   2.56276566e+00,   3.90978319e+00,
#          3.74967321e+00,   3.07100246e+00,   3.42395675e+00,
#          3.92682909e+00,   4.81853604e+00,   5.50002565e+00,
#          2.94243963e+00,   1.06019242e+00,   1.60706051e-02,
#          1.67042797e+00,   5.89183381e-01,   1.69839842e+00,
#          2.02385556e+00,   2.18282857e+00,   1.28277337e+00,
#          1.14668323e+00,   4.69678720e-01,   1.07562019e+00,
#          1.29449326e+00,   4.34878427e-01,   3.88097712e-01,
#          5.90499801e-01,   1.92940730e+00,   1.48758602e-01,
#          2.41675169e+00,   1.02288091e+00])
# -c:158: UserWarning: constraints not satisfied: array([  1.68023414e-01,   9.97684007e-02,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,  -9.93650029e-04,   0.00000000e+00,
#          0.00000000e+00,   7.38562306e-01,   1.63693190e+00,
#          2.15622569e+00,   2.73326996e+00,   2.00627542e+00,
#          1.54211678e+00,   1.07734196e+00,   8.81350266e-01,
#          2.50867950e+00,   2.52916911e+00,   2.02662744e+00,
#          2.96819232e+00,   5.26553671e+00,   5.59169283e+00,
#          6.19432843e+00,   4.35323508e+00,   3.70582010e+00,
#          3.25533798e+00,   2.41510905e+00,   2.23648640e+00,
#          1.72984673e+00,   1.49722066e+00,   6.69914296e-01,
#          1.91055174e+00,   5.24195601e-01,   8.16582064e-01,
#          9.48484119e-04,   3.89704227e-01,   1.48451520e+00,
#          2.25318067e+00,   2.02108519e+00,   2.13450036e+00,
#          3.77389799e+00,   3.86374601e+00,   2.98657831e+00,
#          2.27106298e+00,   3.73670335e+00,   3.06815161e+00,
#          1.99388528e+00,   1.82992756e+00,   6.34383877e-02,
#          6.72993634e-01,   2.28265717e-01,   8.95856711e-01,
#          1.70159445e+00,   7.01050215e-01,   7.75354109e-01,
#          1.68023414e-01,   9.88199166e-02])
# -c:158: UserWarning: constraints not satisfied: array([  1.80040448e-01,   1.34356677e-01,   1.28069560e-01,
#          1.17780395e-01,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,  -1.26415332e-03,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   9.34470800e-01,   1.21482784e+00,
#          1.50765789e+00,   2.19566596e+00,   2.16425325e+00,
#          2.55403972e+00,   1.51808114e+00,   1.44668913e-01,
#          8.42768880e-04,   4.14676072e-01,   1.68545411e+00,
#          1.86965116e+00,   1.00757228e+00,   2.26947605e+00,
#          1.75565703e+00,   2.63454526e+00,   4.11236553e+00,
#          4.78579286e+00,   4.22185123e+00,   4.34238925e+00,
#          4.82273219e+00,   3.73451872e+00,   2.35853258e+00,
#          2.41862718e+00,   1.07644742e+00,   9.97256316e-01,
#          2.71184383e+00,   4.10415274e+00,   4.12601382e+00,
#          4.24095758e+00,   3.19640011e+00,   2.80460843e+00,
#          2.06360339e+00,   2.95455706e+00,   2.68868703e+00,
#          3.59944213e+00,   3.16613548e+00,   2.66171573e+00,
#          3.14930631e+00,   3.67937546e+00,   2.37697911e+00,
#          2.56691739e+00,   2.16035328e+00,   6.71293362e-02,
#          5.76861518e-01,   1.79197679e-01,   1.33935292e-01,
#          1.28069560e-01,   1.17780395e-01])
# -c:158: UserWarning: constraints not satisfied: array([  5.00277338e-01,   4.32633874e-01,   3.69083610e-01,
#          3.17172314e-01,   6.81571228e-02,   3.30935394e-02,
#          1.55249364e-02,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,  -6.88762811e-04,   0.00000000e+00,
#          0.00000000e+00,   5.67779966e-01,   3.16827452e-01,
#          1.38319161e+00,   1.07782942e+00,   9.79573161e-01,
#          1.92534913e+00,   4.35021920e-01,   3.51691729e-01,
#          1.40187601e+00,   1.58908327e+00,   3.16571518e+00,
#          3.32601553e+00,   3.87253370e+00,   2.67647574e+00,
#          2.67574444e+00,   1.79735650e+00,   1.63954514e+00,
#          1.38642194e+00,   6.90193577e-01,   3.81793567e-01,
#          7.53059036e-01,   5.73969009e-04,   6.45459393e-01,
#          5.24998145e-01,   8.19054154e-01,   3.92901591e-01,
#          1.01210739e+00,   2.46172430e+00,   3.73143190e+00,
#          4.39141230e+00,   5.21702399e+00,   6.50352124e+00,
#          5.68491902e+00,   4.74077155e+00,   2.79924480e+00,
#          2.46389377e+00,   1.81491208e+00,   2.82661404e+00,
#          3.01522984e+00,   2.66355930e+00,   2.84016825e+00,
#          1.54568510e+00,   4.32633874e-01,   3.17172314e-01,
#          3.69083610e-01,   5.00277338e-01,   1.55249364e-02,
#          6.75831538e-02,   3.29787456e-02])

# %%
# %%R -i P0,Pa
# P0 = P0[P0>0]
# P0 = P0[P0<1]
# plot(ecdf(P0), col='red', lwd=3)
# Pa = Pa[Pa>0]
# Pa = Pa[Pa<1]
# plot(ecdf(Pa), col='green', lwd=3, add=TRUE)
# plot(ecdf(Pa_correct), col='blue', lwd=3, add=TRUE)
# abline(0,1)
