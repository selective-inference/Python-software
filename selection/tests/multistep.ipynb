# %%
# %load_ext rmagic
import numpy as np

# %% [markdown]
# ## Null model

# %%
reduced = np.load('reduced0_4.0.npy')
covtest = np.load('covtest0_4.0.npy')

# %%
# %%R -i reduced,covtest
# par(mfrow=c(3,3))
# for (i in 1:9) {
#    plot(ecdf(reduced[,i]))
# }

# %%
# %%R
# par(mfrow=c(3,3))
# for (i in 1:9) {
#    plot(ecdf(covtest[,i]))
# }

# %% [markdown]
# ## 1-sparse

# %%
reduced = np.load('reduced1_4.0.npy')
covtest = np.load('covtest1_4.0.npy')

# %%
# %%R -i reduced,covtest
# par(mfrow=c(3,3))
# for (i in 1:9) {
#    plot(ecdf(reduced[,i]))
# }

# %%
# %%R
# par(mfrow=c(3,3))
# for (i in 1:9) {
#    plot(ecdf(covtest[,i]))
# }

# %% [markdown]
# ## 2-sparse

# %%
reduced = np.load('reduced2_4.0.npy')
covtest = np.load('covtest2_4.0.npy')

# %%
# %%R -i reduced,covtest
# par(mfrow=c(3,3))
# for (i in 1:9) {
#    plot(ecdf(reduced[,i]))
# }

# %%
# %%R
# par(mfrow=c(3,3))
# for (i in 1:9) {
#    plot(ecdf(covtest[,i]))
# }

# %% [markdown]
# ## 5-sparse

# %%
reduced = np.load('reduced5_4.0.npy')
covtest = np.load('covtest5_4.0.npy')

# %%
# %%R -i reduced,covtest
# par(mfrow=c(3,3))
# for (i in 1:9) {
#    plot(ecdf(reduced[,i]))
# }

# %%
# %%R
# par(mfrow=c(3,3))
# for (i in 1:9) {
#    plot(ecdf(covtest[,i]))
# }
